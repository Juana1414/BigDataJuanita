# %%
import pandas as pd

# %%
df = pd.read_html("https://finance.yahoo.com/quote/PHP%3DX/history?p=PHP%3DX")[0]

# %%
df
# Out:
#                                                   Date  \
# 0                                         Jan 19, 2021
# 1                                         Jan 18, 2021
# 2                                         Jan 15, 2021
# 3                                         Jan 14, 2021
# 4                                         Jan 13, 2021
# ..                                                 ...
# 96                                        Sep 06, 2020
# 97                                        Sep 03, 2020
# 98                                        Sep 02, 2020
# 99                                        Sep 01, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                              48.0500
# 1                                              48.0120
# 2                                              47.9480
# 3                                              48.0160
# ...

# %%
df.drop([0,100])
# Out:
#             Date     Open     High      Low   Close* Adj Close** Volume
# 1   Jan 18, 2021  48.0120  48.0760  47.9184  47.9275     47.9275      -
# 2   Jan 15, 2021  47.9480  48.1200  47.8957  48.0050     48.0050      -
# 3   Jan 14, 2021  48.0160  48.0950  47.8720  47.9260     47.9260      -
# 4   Jan 13, 2021  48.0650  48.0800  47.9002  48.0700     48.0700      -
# 5   Jan 12, 2021  48.0180  48.1000  47.9199  48.0080     48.0080      -
# ..           ...      ...      ...      ...      ...         ...    ...
# 95  Sep 07, 2020  48.5450  48.6650  48.3900  48.5300     48.5300      -
# 96  Sep 06, 2020  48.6350  48.6850  48.5230  48.5750     48.5750      -
# 97  Sep 03, 2020  48.7200  48.7200  48.4532  48.7150     48.7150      -
# 98  Sep 02, 2020  48.5930  48.6500  48.3950  48.6000     48.6000      -
# 99  Sep 01, 2020  48.5030  48.7000  48.4700  48.5600     48.5600      -
#
# [99 rows x 7 columns]

# %%
df = df.head(30).sort_values(by='Date')

# %%
df=df.astype({"Open":'float',
             "High":'float',
             "Low":'float',
             "Close*":'float',
             "Adj Close**":'float',
             "Volume":'float'})

# %%
df = df.head(10).sort_values(by='Date')

# %%
df = df.astype({"Open" : 'float',
             "High" : 'float',
             "Low" : 'float',
             "Close*" : 'float',
             "Adj Close**" :'float',
             "Volume" : 'float'})

# %%
df = df.head(10).sort_values(by='Date')

# %%
df=df.astype({"Open":'float',
             "High":'float',
             "Low":'float',
             "Close*":'float',
             "Adj Close**":'float'})

# %%
df
# Out:
#             Date    Open    High      Low   Close*  Adj Close** Volume
# 29  Dec 09, 2020  48.180  48.180  47.9193  48.2300      48.2300      -
